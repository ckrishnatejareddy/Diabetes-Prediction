# %% [markdown]
# # Federated diabetes predictor using PIMA Indian diabetes dataset
#
# #### In this code ,I have used PyTorch and PySyft to train a Deep Learning neural network using federated approach.

# %%
# import necessary libraries
import pickle
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader
import time
import copy
import numpy as np
import syft as sy
from syft.frameworks.torch.fl import utils
from syft.workers.websocket_client import WebsocketClientWorker
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
#Initialising the training parameters

class Parser:
    def __init__(self):
        self.epochs = 100
        self.lr = 0.001
        self.test_batch_size = 8
        self.batch_size = 8
        self.log_interval = 10
        self.seed = 1
    
args = Parser()
torch.manual_seed(args.seed)

# %%
# Loading the dataset and getting it ready 

col_Names=["Pregnancies", "Glucose", "BloodPressure", "SkinThickness","Insulin","BMI","DiabetesPedigreeFunction","Age","Outcome"]
df= pd.read_csv("pimadiabetes.csv",names=col_Names)

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# adding a label in the end for clear distinction
df['OutcomeCat'] = np.where(df.Outcome == 1,"Diabetic","Not Diabetic")

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome    OutcomeCat
# 0                     0.627   50        1      Diabetic
# 1                     0.351   31        0  Not Diabetic
# 2                     0.672   32        1      Diabetic
# 3                     0.167   21        0  Not Diabetic
# 4                     2.288   33        1      Diabetic

# %%
#Splitting the data into test and train sets.

X_train, X_test, y_train, y_test = train_test_split(df.drop(['Outcome','OutcomeCat'],axis=1),df.Outcome,test_size  = 0.2, random_state=0)

# %%
x = torch.from_numpy(X_train.to_numpy()).float()
y = torch.from_numpy(y_train.to_numpy()).float()
x_test = torch.from_numpy(X_test.to_numpy()).float()
y_test = torch.from_numpy(y_test.to_numpy()).float()

# %%
train = TensorDataset(x, y)
test = TensorDataset(x_test, y_test)
train_loader = DataLoader(train, batch_size=args.batch_size, shuffle=True)
test_loader = DataLoader(test, batch_size=args.test_batch_size, shuffle=True)

# %%
# Neural network architecture
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(8, 32)
        self.fc2 = nn.Linear(32, 24)
        self.fc4 = nn.Linear(24, 16)
        self.fc3 = nn.Linear(16, 1)

    def forward(self, x):
        x = x.view(-1, 8)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc4(x))
        x = self.fc3(x)
        return x

# %%
# creating virtual workers

hook = sy.TorchHook(torch)
bob_worker = sy.VirtualWorker(hook, id="bob")
alice_worker = sy.VirtualWorker(hook, id="alice")

compute_nodes = [bob_worker, alice_worker]
# Out:
# WARNING:root:Torch was already hooked... skipping hooking process

# %%
# send data to virtual workers
remote_dataset = (list(), list())
train_distributed_dataset = []

for batch_idx, (data,target) in enumerate(train_loader):
    data = data.send(compute_nodes[batch_idx % len(compute_nodes)])
    target = target.send(compute_nodes[batch_idx % len(compute_nodes)])
    remote_dataset[batch_idx % len(compute_nodes)].append((data, target))

# %%
bobs_model = Net()
alices_model = Net()
bobs_optimizer = optim.SGD(bobs_model.parameters(), lr=args.lr)
alices_optimizer = optim.SGD(alices_model.parameters(), lr=args.lr)

# %%
models = [bobs_model, alices_model]
optimizers = [bobs_optimizer, alices_optimizer]

# %%
model = Net()
model
# Out:
# Net(
#   (fc1): Linear(in_features=8, out_features=32, bias=True)
#   (fc2): Linear(in_features=32, out_features=24, bias=True)
#   (fc4): Linear(in_features=24, out_features=16, bias=True)
#   (fc3): Linear(in_features=16, out_features=1, bias=True)
# )

# %%
def update(data, target, model, optimizer):
    model.send(data.location)
    optimizer.zero_grad()
    prediction = model(data)
    loss = F.mse_loss(prediction.view(-1), target)
    loss.backward()
    optimizer.step()
    return model

def train():
    for data_index in range(len(remote_dataset[0])-1):
        for remote_index in range(len(compute_nodes)):
            data, target = remote_dataset[remote_index][data_index]
            models[remote_index] = update(data, target, models[remote_index], optimizers[remote_index])
        for model in models:
            model.get()
        return utils.federated_avg({
            "bob": models[0],
            "alice": models[1]
        })

# %%
def test(federated_model):
    federated_model.eval()
    test_loss = 0
    for data, target in test_loader:
        output = federated_model(data)
        test_loss += F.mse_loss(output.view(-1), target, reduction='sum').item()
        predection = output.data.max(1, keepdim=True)[1]
        
    test_loss /= len(test_loader.dataset)
    print('Test set: Average loss: {:.4f}'.format(test_loss))
    return test_loss

# %%
#save the model with least loss
least_loss = 100000000
for epoch in range(args.epochs):
    start_time = time.time()
    print(f"Epoch Number {epoch + 1}")
    federated_model = train()
    model = federated_model
    test_loss = test(federated_model)
    if(test_loss < least_loss):
        least_loss = test_loss
        torch.save(model.state_dict(), 'pima_model.pt')
    total_time = time.time() - start_time
    print('Communication time over the network', round(total_time, 2), 's\n')
# Out:
# Epoch Number 1
# Test set: Average loss: 2.0174
# Communication time over the network 0.21 s
#
# Epoch Number 2
# Test set: Average loss: 0.1738
# Communication time over the network 0.2 s
#
# Epoch Number 3
# Test set: Average loss: 0.6883
# Communication time over the network 0.17 s
#
# Epoch Number 4
# Test set: Average loss: 0.6709
# Communication time over the network 0.18 s
#
# Epoch Number 5
# Test set: Average loss: 1.0260
# Communication time over the network 0.19 s
#
# Epoch Number 6
# Test set: Average loss: 0.6573
# Communication time over the network 0.21 s
#
# Epoch Number 7
# Test set: Average loss: 4.8092
# Communication time over the network 0.21 s
#
# Epoch Number 8
# Test set: Average loss: 0.2657
# Communication time over the network 0.19 s
#
# Epoch Number 9
# Test set: Average loss: 0.7715
# Communication time over the network 0.19 s
#
# Epoch Number 10
# Test set: Average loss: 2.7647
# Communication time over the network 0.22 s
#
# Epoch Number 11
# Test set: Average loss: 0.1890
# Communication time over the network 0.22 s
#
# Epoch Number 12
# Test set: Average loss: 0.2264
# Communication time over the network 0.2 s
#
# Epoch Number 13
# Test set: Average loss: 1.3738
# Communication time over the network 0.19 s
#
# Epoch Number 14
# Test set: Average loss: 0.6653
# Communication time over the network 0.2 s
#
# Epoch Number 15
# Test set: Average loss: 0.7446
# Communication time over the network 0.2 s
#
# Epoch Number 16
# Test set: Average loss: 0.7521
# Communication time over the network 0.2 s
#
# Epoch Number 17
# Test set: Average loss: 0.1927
# Communication time over the network 0.18 s
#
# Epoch Number 18
# Test set: Average loss: 0.3274
# Communication time over the network 0.17 s
#
# Epoch Number 19
# Test set: Average loss: 0.4048
# Communication time over the network 0.21 s
#
# Epoch Number 20
# Test set: Average loss: 0.4777
# Communication time over the network 0.21 s
#
# Epoch Number 21
# Test set: Average loss: 0.4568
# Communication time over the network 0.23 s
#
# Epoch Number 22
# Test set: Average loss: 7.4463
# Communication time over the network 0.23 s
#
# Epoch Number 23
# Test set: Average loss: 0.8573
# Communication time over the network 0.22 s
#
# Epoch Number 24
# Test set: Average loss: 4.0520
# Communication time over the network 0.22 s
#
# Epoch Number 25
# Test set: Average loss: 0.7887
# Communication time over the network 0.19 s
#
# Epoch Number 26
# Test set: Average loss: 0.3397
# Communication time over the network 0.19 s
#
# Epoch Number 27
# Test set: Average loss: 0.2080
# Communication time over the network 0.2 s
#
# Epoch Number 28
# Test set: Average loss: 0.3008
# Communication time over the network 0.23 s
#
# Epoch Number 29
# Test set: Average loss: 0.4495
# Communication time over the network 0.22 s
#
# Epoch Number 30
# Test set: Average loss: 0.9065
# Communication time over the network 0.23 s
#
# Epoch Number 31
# Test set: Average loss: 0.4335
# Communication time over the network 0.18 s
#
# Epoch Number 32
# Test set: Average loss: 1.1315
# Communication time over the network 0.22 s
#
# Epoch Number 33
# Test set: Average loss: 0.6732
# Communication time over the network 0.23 s
#
# Epoch Number 34
# Test set: Average loss: 0.4085
# Communication time over the network 0.25 s
#
# Epoch Number 35
# Test set: Average loss: 0.6381
# Communication time over the network 0.21 s
#
# Epoch Number 36
# Test set: Average loss: 0.4809
# Communication time over the network 0.22 s
#
# Epoch Number 37
# Test set: Average loss: 0.7712
# Communication time over the network 0.2 s
#
# Epoch Number 38
# Test set: Average loss: 1.8426
# Communication time over the network 0.21 s
#
# Epoch Number 39
# Test set: Average loss: 0.5698
# Communication time over the network 0.22 s
#
# Epoch Number 40
# Test set: Average loss: 0.7722
# Communication time over the network 0.19 s
#
# Epoch Number 41
# Test set: Average loss: 0.3405
# Communication time over the network 0.17 s
#
# Epoch Number 42
# Test set: Average loss: 0.6001
# Communication time over the network 0.17 s
#
# Epoch Number 43
# Test set: Average loss: 0.2570
# Communication time over the network 0.24 s
#
# Epoch Number 44
# Test set: Average loss: 0.4215
# Communication time over the network 0.26 s
#
# Epoch Number 45
# Test set: Average loss: 1.4688
# Communication time over the network 0.24 s
#
# Epoch Number 46
# Test set: Average loss: 0.7491
# Communication time over the network 0.22 s
#
# Epoch Number 47
# Test set: Average loss: 0.6807
# Communication time over the network 0.24 s
#
# Epoch Number 48
# Test set: Average loss: 1.2331
# Communication time over the network 0.2 s
#
# Epoch Number 49
# Test set: Average loss: 1.9033
# Communication time over the network 0.19 s
#
# Epoch Number 50
# Test set: Average loss: 1.0094
# Communication time over the network 0.21 s
#
# Epoch Number 51
# Test set: Average loss: 0.5045
# Communication time over the network 0.22 s
#
# Epoch Number 52
# Test set: Average loss: 0.6730
# Communication time over the network 0.22 s
#
# Epoch Number 53
# Test set: Average loss: 2.2052
# Communication time over the network 0.22 s
#
# Epoch Number 54
# Test set: Average loss: 0.8973
# Communication time over the network 0.22 s
#
# Epoch Number 55
# Test set: Average loss: 0.5594
# Communication time over the network 0.23 s
#
# Epoch Number 56
# Test set: Average loss: 0.7669
# Communication time over the network 0.24 s
#
# Epoch Number 57
# Test set: Average loss: 0.3734
# Communication time over the network 0.23 s
#
# Epoch Number 58
# Test set: Average loss: 0.3822
# Communication time over the network 0.23 s
#
# Epoch Number 59
# Test set: Average loss: 1.0357
# Communication time over the network 0.2 s
#
# Epoch Number 60
# Test set: Average loss: 3.0621
# Communication time over the network 0.21 s
#
# Epoch Number 61
# Test set: Average loss: 0.3694
# Communication time over the network 0.23 s
#
# Epoch Number 62
# Test set: Average loss: 3.1626
# Communication time over the network 0.22 s
#
# Epoch Number 63
# Test set: Average loss: 0.4038
# Communication time over the network 0.22 s
#
# Epoch Number 64
# Test set: Average loss: 3.3038
# Communication time over the network 0.2 s
#
# Epoch Number 65
# Test set: Average loss: 0.2327
# Communication time over the network 0.22 s
#
# Epoch Number 66
# Test set: Average loss: 0.5946
# Communication time over the network 0.27 s
#
# Epoch Number 67
# Test set: Average loss: 1.3841
# Communication time over the network 0.23 s
#
# Epoch Number 68
# Test set: Average loss: 1.2204
# Communication time over the network 0.21 s
#
# Epoch Number 69
# Test set: Average loss: 2.4019
# Communication time over the network 0.22 s
#
# Epoch Number 70
# Test set: Average loss: 0.2813
# Communication time over the network 0.22 s
#
# Epoch Number 71
# Test set: Average loss: 0.9574
# Communication time over the network 0.21 s
#
# Epoch Number 72
# Test set: Average loss: 0.8866
# Communication time over the network 0.22 s
#
# Epoch Number 73
# Test set: Average loss: 0.6304
# Communication time over the network 0.19 s
#
# Epoch Number 74
# Test set: Average loss: 1.1084
# Communication time over the network 0.24 s
#
# Epoch Number 75
# Test set: Average loss: 0.6673
# Communication time over the network 0.18 s
#
# Epoch Number 76
# Test set: Average loss: 0.4889
# Communication time over the network 0.24 s
#
# Epoch Number 77
# Test set: Average loss: 0.9607
# Communication time over the network 0.21 s
#
# Epoch Number 78
# Test set: Average loss: 0.6290
# Communication time over the network 0.25 s
#
# Epoch Number 79
# Test set: Average loss: 0.7489
# Communication time over the network 0.28 s
#
# Epoch Number 80
# Test set: Average loss: 0.4268
# Communication time over the network 0.26 s
#
# Epoch Number 81
# Test set: Average loss: 0.4161
# Communication time over the network 0.25 s
#
# Epoch Number 82
# Test set: Average loss: 2.1522
# Communication time over the network 0.22 s
#
# Epoch Number 83
# Test set: Average loss: 0.4134
# Communication time over the network 0.25 s
#
# Epoch Number 84
# Test set: Average loss: 1.1138
# Communication time over the network 0.26 s
#
# Epoch Number 85
# Test set: Average loss: 0.5730
# Communication time over the network 0.21 s
#
# Epoch Number 86
# Test set: Average loss: 0.8205
# Communication time over the network 0.22 s
#
# Epoch Number 87
# Test set: Average loss: 0.3442
# Communication time over the network 0.27 s
#
# Epoch Number 88
# Test set: Average loss: 0.5655
# Communication time over the network 0.24 s
#
# Epoch Number 89
# Test set: Average loss: 0.6942
# Communication time over the network 0.25 s
#
# Epoch Number 90
# Test set: Average loss: 2.5433
# Communication time over the network 0.17 s
#
# Epoch Number 91
# Test set: Average loss: 0.2968
# Communication time over the network 0.18 s
#
# Epoch Number 92
# Test set: Average loss: 1.2906
# Communication time over the network 0.19 s
#
# Epoch Number 93
# Test set: Average loss: 0.2351
# Communication time over the network 0.25 s
#
# Epoch Number 94
# Test set: Average loss: 0.4696
# Communication time over the network 0.21 s
#
# Epoch Number 95
# Test set: Average loss: 0.9102
# Communication time over the network 0.19 s
#
# Epoch Number 96
# Test set: Average loss: 0.2295
# Communication time over the network 0.21 s
#
# Epoch Number 97
# Test set: Average loss: 0.2228
# Communication time over the network 0.18 s
#
# Epoch Number 98
# Test set: Average loss: 0.5786
# Communication time over the network 0.19 s
#
# Epoch Number 99
# Test set: Average loss: 2.5061
# Communication time over the network 0.2 s
#
# Epoch Number 100
# Test set: Average loss: 0.5874
# Communication time over the network 0.24 s

# %%
final_model = Net()
final_model.load_state_dict(torch.load('pima_model.pt'))
# Out:
# <All keys matched successfully>

# %%
final_model.eval()
# Out:
# Net(
#   (fc1): Linear(in_features=8, out_features=32, bias=True)
#   (fc2): Linear(in_features=32, out_features=24, bias=True)
#   (fc4): Linear(in_features=24, out_features=16, bias=True)
#   (fc3): Linear(in_features=16, out_features=1, bias=True)
# )
